# %% [markdown]
# # 转换 置换， 向量空间R

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 向量空间（Vector Space）

# %% [markdown]
# * 所有向量空间都必须包含原点(Origin)
# * 向量空间中任意向量的数乘，**求和运算得到的向量也是在空间**中，即**向量空间要满足加法封闭和数乘封闭**。
