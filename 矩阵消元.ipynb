# %% [markdown]
# # 矩阵消元

# %% [markdown]
# 这个方法最早由高斯提出，我们以前**解方程组的时候都会使用，现在来看如何使用矩阵实现消元法**。

# %% [markdown]
# # 消元法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 消元矩阵

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 逆

# %% [markdown]
# ![image.png](attachment:image.png)
